# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cust = pd.read_excel(r"C:\Users\Gyegn\OneDrive\Desktop\New Microsoft Excel Worksheet (2).xlsx")

# %%
cust.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0      "835 Frank Tunnel Wrightmouth  MI 82180-9605"            Violet
# 1    "4547 Archer Common Diazchester  CA 06566-8576"         DarkGreen
# 2  "24645 Valerie Unions Suite 582 Cobbborough  D...            Bisque
# 3  "1414 David Throughway Port Jason  OH 22070-1220"       SaddleBrown
# 4  "14023 Rodriguez Passage Port Jacobville  PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
cust.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
corr_matrix = cust.corr()

# %%
fig,ax = plt.subplots(figsize=(10,8))
cax = ax.matshow(corr_matrix, cmap = "coolwarm")
fig.colorbar(cax)

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm',vmin=-1,vmax=1)
# Out:
# <AxesSubplot:>

# %%
cust.shape
# Out:
# (501, 8)

# %%
cust.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 35.2+ KB

# %%
cust = cust.dropna()

# %% [markdown]
# # Time on Website vs Yearly Amount Spent

# %%
cust.plot(kind = 'scatter', x = 'Time on Website', y = 'Yearly Amount Spent')
# Out:
# <AxesSubplot:xlabel='Time on Website', ylabel='Yearly Amount Spent'>

# %%
sns.jointplot(x = 'Time on Website', y = 'Yearly Amount Spent', data = cust)

# %% [markdown]
# The two plots are of same kind made using two different libraries i.e matplotlib and seaborn. This is to check the correlation between Time on Website and Yearly Amount Spent. The graph shows that the points are widely scattered, which depicts a low correlation between them. Further, the hist on the top and right shows the distribution type of Time on Website and Yearly Amount Spent respectively. Both of shows a normal distribution roughly.

# %% [markdown]
# # Time on App vs Yearly Amount Spent

# %%
cust.plot(x = 'Time on App', y = 'Yearly Amount Spent', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Time on App', ylabel='Yearly Amount Spent'>

# %%
sns.jointplot(x = 'Time on App', y = 'Yearly Amount Spent', data = cust)

# %% [markdown]
# This is the plot between time on app and yearly amount spent. The graph here depicts strong positive correlation compared to the previous one. The data is more clustered in diagonal manner.

# %% [markdown]
# # Heat Map and Correlation Matrix

# %%
corr_matrix = cust.corr()
corr_matrix
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
fig,ax = plt.subplots(figsize = (10,8))
cax = ax.matshow(corr_matrix, cmap = 'coolwarm')
fig.colorbar(cax)

# %%
sns.heatmap(corr_matrix, cmap = 'coolwarm', vmin = -1, vmax = 1, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Upon using the matplotlib and seaborn for correlation matrix, it was found seaborn is the simple way to create a heap map over matplotlib. It is also possible to make a heat map using matplotlib. But requires many lines of code which is possible with a single line of code using seaborn.
# The heat map depicts a very strong positive correlation between 'Leanth of Membership' and 'Yearly Amount Spent'. Further it also clarifies that the positive correlation observed between Time on App and Yearly amount spent is also not a strong kind of relation in overall observation.

# %%
sns.jointplot(x = 'Length of Membership', y = 'Yearly Amount Spent', data = cust, kind = 'reg')

# %%
sns.lmplot(x = 'Length of Membership', y = 'Yearly Amount Spent', data = cust)

# %% [markdown]
# Both the commands may provide same kind of plot for now. But for regression plots, it is 'sns.lmplot' the most reliable one to make more customizations than that to 'sns.jointplot(kind='reg')'

# %% [markdown]
# # Training and Testing data Split

# %%
 X = cust[['Time on App',
       'Time on Website', 'Length of Membership','Avg. Session Length']]
y = cust['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (350, 4)

# %%
X_train.head()
# Out:
#      Time on App  Time on Website  Length of Membership  Avg. Session Length
# 202    11.340036        37.039514              3.811248            31.525752
# 428    14.039867        37.022269              3.738225            31.862741
# 392    11.514949        37.128039              4.662845            33.258238
# 86     12.517666        37.151921              2.669942            33.877779
# 443    12.504220        37.645839              4.051382            33.025020

# %%
y_train.head()
# Out:
# 202    443.965627
# 428    556.298141
# 392    549.131573
# 86     487.379306
# 443    561.516532
# Name: Yearly Amount Spent, dtype: float64

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Train/fit lm model

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train.isnull().sum()
# Out:
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Avg. Session Length     0
# dtype: int64

# %%
X_test.shape
# Out:
# (150, 4)

# %%
print(lm.coef_)
# Out:
# [38.59015875  0.19040528 61.27909654 25.98154972]

# %% [markdown]
# Predictions

# %%
predictions = lm.predict(X_test)

# %%
predictions.shape
# Out:
# (150,)

# %%
plt.scatter(y_test, predictions)

# %%
residuals = (y_test - predictions)

# %%
residuals**2
# Out:
# 147    1.431172
# 346    3.977230
# 423    3.521249
# 17    -3.822028
# 259   -0.080551
# Name: Yearly Amount Spent, dtype: float64

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 79.81305165097456

# %%
import sklearn.metrics as metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 7.228148653430834

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))
# Out:
# 8.93381506697864

# %%
residuals.plot(kind = 'hist')
# residuals.plot()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot((residuals))
# Out:
# C:\Users\Gyegn\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Density'>

# %%
pd.DataFrame(lm.coef_,X_test.columns, columns = ['coefficients'])
# Out:
#                       coefficients
# Time on App              38.590159
# Time on Website           0.190405
# Length of Membership     61.279097
# Avg. Session Length      25.981550

# %% [markdown]
# The above observations are the weights of the independent values assigned to find the dependent values. And here it shows the weight of Time on App is having heavy impact on Yearly Amount Spent than that of the Time on Web. Thereby it can be concluded saying that Time on App is to be invested and focused more by the merchant.
